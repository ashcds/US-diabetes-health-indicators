# %% [markdown]
# #### Data Import and EDA

# %%
# Standard imports 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pip install ucimlrepo
# Out:
# ...
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Import the dataset 
from ucimlrepo import fetch_ucirepo

# fetch dataset 
cdc_diabetes_health_indicators = fetch_ucirepo(id=891) 

X_data = cdc_diabetes_health_indicators.data.features
y_data = cdc_diabetes_health_indicators.data.target

# Convert to pandas DataFrame
X_diabetes = pd.DataFrame(X_data, columns=cdc_diabetes_health_indicators.data.feature_names)
X_diabetes
# Out:
#         HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0            1         1          1   40       1       0
# 1            0         0          0   25       1       0
# 2            1         1          1   28       0       0
# 3            1         0          1   27       0       0
# 4            1         1          1   24       0       0
# ...        ...       ...        ...  ...     ...     ...
# 253675       1         1          1   45       0       0
# 253676       1         1          1   18       0       0
# 253677       0         0          1   28       0       0
# 253678       1         0          1   23       0       0
# 253679       1         1          1   25       0       0
#
#         HeartDiseaseorAttack  PhysActivity  Fruits  Veggies  ...  \
# 0                          0             0       0        1  ...
# 1                          0             1       0        0  ...
# 2                          0             0       1        0  ...
# ...

# %%
X_diabetes['Income'].value_counts()
# Out:
# Income
# 8    90385
# 7    43219
# 6    36470
# 5    25883
# 4    20135
# 3    15994
# 2    11783
# 1     9811
# Name: count, dtype: int64
